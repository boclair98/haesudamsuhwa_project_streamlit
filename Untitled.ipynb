# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
seawater = pd.read_csv('해수담수화 데이터1.csv',encoding='cp949')

# %%
seawater.columns
# Out:
# Index(['희승', '관측일자', '수온', '수소이온농도', '1차 인입압력', '2차 인입압력', '1차 생산수 TDS',
#        '2차 생산수 TDS', '1차 전력량(에너지 소비량)', '2차 전력량(에너지 소비량)', '전체 전력량', '절약 사용량',
#        '전기전도도', '용존산소량', '탁도', '일사량', '기온', '상대습도', '풍속', '풍향', '강수량', '염분',
#        '클로로필', '화학적산소요구량', '총질소', '총인', '암모니아질소', '질산질소', '인산성인', '규산규소',
#        '남조류', 'Unnamed: 31', 'Unnamed: 32'],
#       dtype='object')

# %%
seawater.drop(['전기전도도', '용존산소량', '탁도', '일사량', '기온', '상대습도', '풍속', '풍향', '강수량', '염분',
       '클로로필', '화학적산소요구량', '총질소', '총인', '암모니아질소', '질산질소', '인산성인', '규산규소',
       '남조류', 'Unnamed: 31', 'Unnamed: 32','희승'],axis=1, inplace=True)

# %%
seawater.dropna(axis = 0,inplace=True)

# %%
seawater.reset_index(drop=True,inplace=True)

# %%
seawater
# Out:
#                   관측일자    수온  수소이온농도  1차 인입압력  2차 인입압력  1차 생산수 TDS  \
# 0      2021-01-01 0:00   4.7    7.98    57.74    26.86       35.28
# 1      2021-01-01 1:00  4.96    7.98    57.52    26.58       36.07
# 2      2021-01-01 2:00  4.99    7.97    57.49    26.55       36.16
# 3      2021-01-01 3:00  4.98    7.97    57.50    26.56       36.16
# 4      2021-01-01 4:00  5.03    7.99    57.46    26.51       36.28
# ...                ...   ...     ...      ...      ...         ...
# 6127  2021-12-31 19:00  5.02    8.00    57.47    26.52       36.25
# 6128  2021-12-31 20:00  4.94    8.01    57.54    26.60       36.00
# 6129  2021-12-31 21:00  4.97    8.01    57.51    26.57       36.10
# 6130  2021-12-31 22:00  4.88    8.00    57.59    26.67       35.82
# 6131  2021-12-31 23:00  4.74    7.99    57.71    26.81       35.40
#
#       2차 생산수 TDS  1차 전력량(에너지 소비량)  2차 전력량(에너지 소비량)  전체 전력량  절약 사용량
# 0           0.67             2.61             1.04    3.65     3.6
# ...

# %%
seawater.dtypes
# Out:
# 관측일자                object
# 수온                  object
# 수소이온농도             float64
# 1차 인입압력            float64
# 2차 인입압력            float64
# 1차 생산수 TDS         float64
# 2차 생산수 TDS         float64
# 1차 전력량(에너지 소비량)    float64
# 2차 전력량(에너지 소비량)    float64
# 전체 전력량             float64
# 절약 사용량             float64
# dtype: object

# %%
seawater['수온'] = seawater['수온'].astype('float')

# %%
fig,axs = plt.subplots(4)
plt.rcParams['font.family'] = 'Malgun Gothic'
axs[0].plot(seawater['관측일자'],seawater['수온'],alpha=0.5)
axs[1].plot(seawater['관측일자'],seawater['1차 인입압력'],alpha=0.5)
axs[2].plot(seawater['관측일자'],seawater['전체 전력량'],alpha=0.5)
axs[3].plot(seawater['관측일자'],seawater['절약 사용량'],alpha=0.5)
plt.show()

# %%
seawater.corr()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15556\3952019681.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   seawater.corr()
#                        수온    수소이온농도   1차 인입압력   2차 인입압력  1차 생산수 TDS  \
# 수온               1.000000 -0.254924 -0.982454 -0.246762    0.048684
# 수소이온농도          -0.254924  1.000000  0.239707  0.060256   -0.017464
# 1차 인입압력         -0.982454  0.239707  1.000000  0.249754   -0.048406
# 2차 인입압력         -0.246762  0.060256  0.249754  1.000000   -0.012427
# 1차 생산수 TDS       0.048684 -0.017464 -0.048406 -0.012427    1.000000
# 2차 생산수 TDS       0.407361 -0.140147 -0.381710 -0.097259    0.017472
# 1차 전력량(에너지 소비량) -0.980009  0.239503  0.996751  0.248808   -0.048330
# 2차 전력량(에너지 소비량) -0.987112  0.245551  0.998007  0.249948   -0.048098
# ...

# %%
seawater.drop(['1차 생산수 TDS','2차 생산수 TDS','1차 전력량(에너지 소비량)','2차 전력량(에너지 소비량)'],axis=1,inplace=True)

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
sns.heatmap(seawater.corr(),annot=True)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15556\3705512904.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(seawater.corr(),annot=True)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# C:\Users\User\AppData\Roaming\Python\Python39\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
seawater
# Out:
#                   관측일자    수온  수소이온농도  1차 인입압력  2차 인입압력  전체 전력량  절약 사용량
# 0      2021-01-01 0:00  4.70    7.98    57.74    26.86    3.65     3.6
# 1      2021-01-01 1:00  4.96    7.98    57.52    26.58    3.63     3.6
# 2      2021-01-01 2:00  4.99    7.97    57.49    26.55    3.62     3.6
# 3      2021-01-01 3:00  4.98    7.97    57.50    26.56    3.62     3.6
# 4      2021-01-01 4:00  5.03    7.99    57.46    26.51    3.62     3.6
# ...                ...   ...     ...      ...      ...     ...     ...
# 6127  2021-12-31 19:00  5.02    8.00    57.47    26.52    3.62     3.6
# 6128  2021-12-31 20:00  4.94    8.01    57.54    26.60    3.63     3.6
# 6129  2021-12-31 21:00  4.97    8.01    57.51    26.57    3.63     3.6
# 6130  2021-12-31 22:00  4.88    8.00    57.59    26.67    3.63     3.6
# 6131  2021-12-31 23:00  4.74    7.99    57.71    26.81    3.64     3.6
#
# [6132 rows x 7 columns]

# %%
seawater.drop(['관측일자','수온','수소이온농도','전체 전력량'],axis=1,inplace=True)

# %%
seawater
# Out:
#       1차 인입압력  2차 인입압력  절약 사용량
# 0       57.74    26.86     3.6
# 1       57.52    26.58     3.6
# 2       57.49    26.55     3.6
# 3       57.50    26.56     3.6
# 4       57.46    26.51     3.6
# ...       ...      ...     ...
# 6127    57.47    26.52     3.6
# 6128    57.54    26.60     3.6
# 6129    57.51    26.57     3.6
# 6130    57.59    26.67     3.6
# 6131    57.71    26.81     3.6
#
# [6132 rows x 3 columns]

# %%
seawater1 =pd.read_csv('해수담수화 데이터1.csv',encoding='cp949')

# %%
seawater1.columns
# Out:
# Index(['희승', '관측일자', '수온', '수소이온농도', '1차 인입압력', '2차 인입압력', '1차 생산수 TDS',
#        '2차 생산수 TDS', '1차 전력량(에너지 소비량)', '2차 전력량(에너지 소비량)', '전체 전력량', '절약 사용량',
#        '전기전도도', '용존산소량', '탁도', '일사량', '기온', '상대습도', '풍속', '풍향', '강수량', '염분',
#        '클로로필', '화학적산소요구량', '총질소', '총인', '암모니아질소', '질산질소', '인산성인', '규산규소',
#        '남조류', 'Unnamed: 31', 'Unnamed: 32'],
#       dtype='object')

# %%
seawater1.drop(['희승', '관측일자', '수온', '수소이온농도','1차 생산수 TDS',
       '2차 생산수 TDS', '1차 전력량(에너지 소비량)', '2차 전력량(에너지 소비량)','절약 사용량',
       '전기전도도', '용존산소량', '탁도', '일사량', '기온', '상대습도', '풍속', '풍향', '강수량', '염분',
       '클로로필', '화학적산소요구량', '총질소', '총인', '암모니아질소', '질산질소', '인산성인', '규산규소',
       '남조류', 'Unnamed: 31', 'Unnamed: 32'],axis=1,inplace=True)

# %%
seawater1
# Out:
#       1차 인입압력  2차 인입압력  전체 전력량
# 0       57.74    26.86    3.65
# 1       57.52    26.58    3.63
# 2       57.49    26.55    3.62
# 3       57.50    26.56    3.62
# 4       57.46    26.51    3.62
# ...       ...      ...     ...
# 8745    57.59    26.67    3.63
# 8746    57.71    26.81    3.64
# 8747      NaN      NaN    0.00
# 8748      NaN      NaN    0.00
# 8749      NaN      NaN    0.00
#
# [8750 rows x 3 columns]

# %%
target = '1차 인입압력'
x = seawater.drop(target,axis=1)
y = seawater[target]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import *
model = RandomForestRegressor(random_state=65)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=65)

# %%
y_pred = model.predict(x_test)

# %%
plt.scatter(y_test,y_pred)
plt.show()

# %%
seawater1['수온']=seawater1['수온'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '수온'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
seawater1
# Out:
#       1차 인입압력  2차 인입압력  전체 전력량
# 0       57.74    26.86    3.65
# 1       57.52    26.58    3.63
# 2       57.49    26.55    3.62
# 3       57.50    26.56    3.62
# 4       57.46    26.51    3.62
# ...       ...      ...     ...
# 8745    57.59    26.67    3.63
# 8746    57.71    26.81    3.64
# 8747      NaN      NaN    0.00
# 8748      NaN      NaN    0.00
# 8749      NaN      NaN    0.00
#
# [8750 rows x 3 columns]

# %%
seawater1.dropna(axis=0,inplace=True)

# %%
target = '1차 인입압력'
x1 = seawater1.drop(target,axis=1)
y1 = seawater1[target]

# %%
x_train1,x_test1,y_train1,y_test1 = train_test_split(x1,y1,test_size=0.3)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import *
model1 = RandomForestRegressor(random_state=65)
model1.fit(x_train1,y_train1)
y_pred1 = model1.predict(x_test1)

# %%
y_pred1
# Out:
# array([52.93528702, 58.1198    , 47.1801    , ..., 53.51      ,
#        50.64063794, 53.2437    ])

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
axs[0].plot(y_pred,y_pred,alpha=0.5)
axs[1].plot(y_pred1,y_pred1,alpha=0.5)

plt.show()

# %%
print(y_pred)
print(y_pred1)
# Out:
# [59.1637     49.13408714 47.65615006 ... 57.89       55.89805
#  57.6942    ]
# [52.93528702 58.1198     47.1801     ... 53.51       50.64063794
#  53.2437    ]

# %%
seawater.isna().sum()
# Out:
# 1차 인입압력    0
# 2차 인입압력    0
# 절약 사용량     0
# dtype: int64

# %%
seawater1.isna().sum()
# Out:
# 1차 인입압력    0
# 2차 인입압력    0
# 전체 전력량     0
# dtype: int64

# %%
seawater.value_counts()
# Out:
# 1차 인입압력  2차 인입압력  절약 사용량
# 50.07    17.02    2.9       25
#          17.01    2.9       25
# 49.10    15.66    2.8       21
# 49.11    15.68    2.8       20
# 49.07    15.62    2.8       20
#                             ..
# 52.78    20.62    3.1        1
# 52.81    20.65    3.1        1
#          20.68    3.1        1
# 52.82    20.67    3.2        1
# 60.28    30.00    3.8        1
# Length: 1949, dtype: int64

# %%
seawater['절약 사용량'].value_counts()
# Out:
# 2.9    748
# 2.7    704
# 3.6    616
# 3.0    545
# 2.8    544
# 3.5    522
# 3.2    516
# 3.7    511
# 2.6    376
# 3.1    309
# 3.3    258
# 3.8    245
# 3.4    219
# 2.5     19
# Name: 절약 사용량, dtype: int64

# %%
seawater
# Out:
#       1차 인입압력  2차 인입압력  절약 사용량
# 0       57.74    26.86     3.6
# 1       57.52    26.58     3.6
# 2       57.49    26.55     3.6
# 3       57.50    26.56     3.6
# 4       57.46    26.51     3.6
# ...       ...      ...     ...
# 6127    57.47    26.52     3.6
# 6128    57.54    26.60     3.6
# 6129    57.51    26.57     3.6
# 6130    57.59    26.67     3.6
# 6131    57.71    26.81     3.6
#
# [6132 rows x 3 columns]

# %%
seawater1.dropna(axis=0,inplace=True)

# %%
seawater1.reset_index(drop=True,inplace=True)

# %%
import joblib
joblib.dump(model,'./random_model.pkl')
# Out:
# ['./random_model.pkl']

# %%
data = pd.read_csv('최종RO공정데이터.csv',encoding='cp949')

# %%
data
# Out:
#                   관측일자    수온  수소이온농도  1차 인입압력  2차 인입압력  1차 생산수 TDS  \
# 0      2021-01-01 0:00  4.70    7.98  59.7400    26.86       35.28
# 1      2021-01-01 1:00  4.96    7.98  57.5200    26.58       36.07
# 2      2021-01-01 2:00  4.99    7.97  57.4900    26.55       36.16
# 3      2021-01-01 3:00  4.98    7.97  57.5000    26.56       36.16
# 4      2021-01-01 4:00  5.03    7.99  59.4600    26.51       36.28
# ...                ...   ...     ...      ...      ...         ...
# 8742  2021-12-31 19:00  5.02    8.00  59.7688    26.52       36.25
# 8743  2021-12-31 20:00  4.94    8.01  57.5400    26.60       36.00
# 8744  2021-12-31 21:00  4.97    8.01  57.5100    26.57       36.10
# 8745  2021-12-31 22:00  4.88    8.00  57.5900    26.67       35.82
# 8746  2021-12-31 23:00  4.74    7.99  57.7100    26.81       35.40
#
#       2차 생산수 TDS  1차 전력량(에너지 소비량)  2차 전력량(에너지 소비량)  전체 전력량
# 0           0.67             2.61             1.04    3.65
# ...

# %%
data.columns
# Out:
# Index(['관측일자', '수온', '수소이온농도', '1차 인입압력', '2차 인입압력', '1차 생산수 TDS',
#        '2차 생산수 TDS', '1차 전력량(에너지 소비량)', '2차 전력량(에너지 소비량)', '전체 전력량'],
#       dtype='object')

# %%
df.drop(['관측일자', '2차 인입압력', '1차 생산수 TDS',
       '2차 생산수 TDS', '1차 전력량(에너지 소비량)', '2차 전력량(에너지 소비량)', '전체 전력량'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df.drop(['관측일자', '2차 인입압력', '1차 생산수 TDS',
#       2        '2차 생산수 TDS', '1차 전력량(에너지 소비량)', '2차 전력량(에너지 소비량)', '전체 전력량'],axis=1,inplace=True)
#
# NameError: name 'df' is not defined

# %%
pip install streamlit-camera-input-live
# Out:
# ...
#
# ...
